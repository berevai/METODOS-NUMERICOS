# %% [markdown]
# <a href="https://colab.research.google.com/github/berevai/METODOS-NUMERICOS/blob/main/M%C3%A9todos%20Disecci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Método de bisección**

# %% [markdown]
# Queremos resolver la ecuación $xˆ3+4xˆ2-10=0$ en el intervalo $[1,2]$
#
# Para aplicar el **método de bisección** verificamos qué la función $f(x)$ evaluada en los extremos opuestos tiene signos opuestos

# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
	return x**3 + 4*x**2 - 10.0

# %% [markdown]
# Graficado f(x)

# %%
x=np.linspace(0,3) #genera una retícula o partición
plt.plot(x,f(x))
plt.title("Gráfica $f(x)= x**3 + 4*x**2 - 10.0$")
plt.xlabel("$x$")
plt.ylabel("$f(x)$")
plt.scatter(1,0,color="pink", label="raíz")
plt.axhline(y=0, color="red") #trazar línea horizontal

# %% [markdown]
# Evaluando la función en el intervalo

# %%
f(2)
# Out:
# 14.0

# %%
f(1)
# Out:
# -5.0

# %% [markdown]
# Hiper parámetros

# %%
#Ingreso de datos de entrada para los diferentes métodos a trabajar
a=1
b=1


#Guarda valores iniciales
a0=a
b0=b

tol=0.000001 #error
nmax=100 #número máx de iteraciones
error=100 #valor inicial del error
niter=0 #contador de iteraciones

# %%
# Método de Bisección

# evaluo primer valor medio
m = a + (b - a)/2

#Evaluacion de la función en los puntos a, b y m
fa = f(a)
fb = f(b)
fm = f(m)

print("# iter\t\t a \t\t f(a) \t\t b \t\t f(b) \t\t m \t\t f(m) \t\t error")
print("{0} \t\t {1:6.4f} \t {2:6.4f} \t {3:6.4f} \t {4:6.4f} \t {5:6.4f} \t {6:6.4f} \t {7:6.4f}".format(niter, a0, fa, b0, fb, m, fm, error ))

# ciclo iterativo
while error > tol and niter < nmax: #Criterios de terminación
  m = a + (b - a) / 2
  if np.sign(fa) == np.sign(fm):#Esta función devuelve signo
      a = m
      fa = f(a)
  else:
      b = m
      fb = f(b)

  m = a + (b - a)/2
  fm = f(m)
  error = abs(b - a)
  niter += 1
  print("{0} \t\t {1:6.6f} \t {2:6.6f} \t {3:6.6f} \t {4:6.6f} \t {5:6.6f} \t {6:6.6f} \t {7:6.6f}".format(niter, a, fa, b, fb, m, fm, error ))

print("La raíz de la función dada en el intervalo [{0:6.4f},{1:6.4f}] es {2:6.7f}".format(a0,b0,m))
# Out:
# # iter		 a 		 f(a) 		 b 		 f(b) 		 m 		 f(m) 		 error
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1882/1908687426.py in <cell line: 0>()
#      10
#      11 print("# iter\t\t a \t\t f(a) \t\t b \t\t f(b) \t\t m \t\t f(m) \t\t error")
# ---> 12 print("{0} \t\t {1:6.4f} \t {2:6.4f} \t {3:6.4f} \t {4:6.4f} \t {5:6.4f} \t {6:6.4f} \t {7:6.4f}".format(niter, a0, fa, b0, fb, m, fm, error ))
#      13
#      14 # ciclo iterativo
#
# NameError: name 'niter' is not defined
